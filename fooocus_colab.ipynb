# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 43.3 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6718, done.
# remote: Total 6718 (delta 0), reused 0 (delta 0), pack-reused 6718 (from 1)
# Receiving objects: 100% (6718/6718), 33.26 MiB | 21.27 MiB/s, done.
# Resolving deltas: 100% (3874/3874), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 9.23MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 8.52MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 43.9MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 237MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:35<00:00, 202MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 134MB/s]
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://34c517f5a26fb682d3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 2024-11-07 16:11:58.162276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-07 16:11:58.380379: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-07 16:11:58.437440: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-07 16:11:58.816938: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-07 16:12:00.239283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Started worker with PID 419
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://34c517f5a26fb682d3.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7886995718416005584
# [Parameters] CFG = 4
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Create a 30-second animated video that features a motivational quote designed to inspire and uplift viewers. The animation should have a visually appealing, modern style with smooth transitions. Incorporate a positive background soundtrack and ambient elements that align with the theme of self-improvement and personal growth. Include dynamic typography to display the quote in an impactful way, ensuring the text is easy to read, and add subtle, relevant animations around the text (like light bursts, soft glows, or color shifts) to draw attention. The animation should end with a final frame showing the quote clearly for a few seconds to allow viewers to absorb the message, real sincere, focused, true inspirational, dramatic, detailed, quality, handsome, stunning, romantic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Create a 30-second animated video that features a motivational quote designed to inspire and uplift viewers. The animation should have a visually appealing, modern style with smooth transitions. Incorporate a positive background soundtrack and ambient elements that align with the theme of self-improvement and personal growth. Include dynamic typography to display the quote in an impactful way, ensuring the text is easy to read, and add subtle, relevant animations around the text (like light bursts, soft glows, or color shifts) to draw attention. The animation should end with a final frame showing the quote clearly for a few seconds to allow viewers to absorb the message, dramatic atmosphere, detailed, intricate, epic composition, highly detail, joyful, mystical, inspiring, thought
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 3.34 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.74 seconds
# 100% 30/30 [00:26<00:00,  1.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 31.58 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.77 seconds
# 100% 30/30 [00:26<00:00,  1.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 30.34 seconds
# [Fooocus] Processing enhance ...
# Enhancement image time: 0.00 seconds
# Enhancement image time: 0.00 seconds
# Processing time (total): 61.93 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 65.37 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.01 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 3
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 9187798849874232536
# [Parameters] CFG = 7
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Create a 30-second animated video that features a motivational quote designed to inspire and uplift viewers. The animation should have a visually appealing, modern style with smooth transitions. Incorporate a positive background soundtrack and ambient elements that align with the theme of self-improvement and personal growth. Include dynamic typography to display the quote in an impactful way, ensuring the text is easy to read, and add subtle, relevant animations around the text (like light bursts, soft glows, or color shifts) to draw attention. The animation should end with a final frame showing the quote clearly for a few seconds to allow viewers to absorb the message, created very inspirational, lively, real, glorious, epic, cinematic, extremely detailed, shining bright
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Create a 30-second animated video that features a motivational quote designed to inspire and uplift viewers. The animation should have a visually appealing, modern style with smooth transitions. Incorporate a positive background soundtrack and ambient elements that align with the theme of self-improvement and personal growth. Include dynamic typography to display the quote in an impactful way, ensuring the text is easy to read, and add subtle, relevant animations around the text (like light bursts, soft glows, or color shifts) to draw attention. The animation should end with a final frame showing the quote clearly for a few seconds to allow viewers to absorb the message, perfect balance, cinematic, dramatic atmosphere, unique, aesthetic, very inspirational, inspiring, real, creative
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.58 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.66 seconds
#  90% 27/30 [00:24<00:02,  1.08it/s]
# User stopped
# [Fooocus] Processing enhance ...
# Processing time (total): 26.56 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 28.18 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 3
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3044183335202383479
# [Parameters] CFG = 7
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Create a 30-second animated video that features a motivational quote designed to inspire and uplift viewers. The animation should have a visually appealing, modern style with smooth transitions. Incorporate a positive background soundtrack and ambient elements that align with the theme of self-improvement and personal growth. Include dynamic typography to display the quote in an impactful way, ensuring the text is easy to read in english language, and add subtle, relevant animations around the text (like light bursts, soft glows, or color shifts) to draw attention. The animation should end with a final frame showing the quote clearly for a few seconds to allow viewers to absorb the message, clear focus, creative, cinematic, highly detailed, intricate, very inspirational, inspiring
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Create a 30-second animated video that features a motivational quote designed to inspire and uplift viewers. The animation should have a visually appealing, modern style with smooth transitions. Incorporate a positive background soundtrack and ambient elements that align with the theme of self-improvement and personal growth. Include dynamic typography to display the quote in an impactful way, ensuring the text is easy to read in english language, and add subtle, relevant animations around the text (like light bursts, soft glows, or color shifts) to draw attention. The animation should end with a final frame showing the quote clearly for a few seconds to allow viewers to absorb the message, dramatic atmosphere, detailed, intricate, epic composition, highly detail, magical, mystical
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.78 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.89 seconds
# 100% 30/30 [00:26<00:00,  1.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 31.44 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 100% 30/30 [00:27<00:00,  1.08it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 31.27 seconds
# [Fooocus] Processing enhance ...
# Enhancement image time: 0.00 seconds
# Enhancement image time: 0.00 seconds
# Processing time (total): 62.71 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 64.57 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.91 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 3
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7969830305346607770
# [Parameters] CFG = 7
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Generate an abstract, animated video background that complements a motivational quote displayed in bold, clear English text. Use soft color gradients, smooth shapes, and subtle motion effects like flowing lines or particles. Ensure the text is legible, centered, and overlays the background with contrasting colors for easy readability. The background should convey an uplifting and inspiring mood, with gentle, continuous animation (such as slow-moving waves, swirling shapes, or light bursts) to keep the visual engaging. Display the quote prominently in the middle and allow the text to remain visible for at least five seconds, dynamic composition, great focus, creative, cinematic, aesthetic, very inspirational, stunning, unique, gorgeous, attractive, elegant, intricate, highly detailed
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Generate an abstract, animated video background that complements a motivational quote displayed in bold, clear English text. Use soft color gradients, smooth shapes, and subtle motion effects like flowing lines or particles. Ensure the text is legible, centered, and overlays the background with contrasting colors for easy readability. The background should convey an uplifting and inspiring mood, with gentle, continuous animation (such as slow-moving waves, swirling shapes, or light bursts) to keep the visual engaging. Display the quote prominently in the middle and allow the text to remain visible for at least five seconds, dynamic composition, ambient atmosphere, detailed, intricate, highly complex, colorful, epic, cinematic, very inspirational, beautiful, stunning, classic, modern
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 2.02 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.79 seconds
# 100% 30/30 [00:26<00:00,  1.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 31.44 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 30/30 [00:27<00:00,  1.08it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 31.39 seconds
# [Fooocus] Processing enhance ...
# Enhancement image time: 0.00 seconds
# Enhancement image time: 0.00 seconds
# Processing time (total): 62.83 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 64.92 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.01 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 3
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 160520310109641588
# [Parameters] CFG = 7
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Preparing Fooocus text #1 ...
# [Prompt Expansion] Create an animated video featuring an abstract, colorful background with smooth gradients and flowing shapes to convey an inspiring atmosphere. In the center, display the following motivational quote in bold, clear English text: 'Your potential is endless; keep pushing forward.' The text should be large, legible, and contrasted against the background to stand out. Use a subtle animation effect on the text (like a slight glow or fade-in effect) and keep it visible for at least 5-10 seconds. The background should have gentle, continuous movement to make the visual engaging without distracting from the message, focus, highly detailed, bright color, dramatic, dynamic composition, elegant, intricate, epic, stunning, rich detail, cinematic, unique, best, fair, artistic
# [Fooocus] Preparing Fooocus text #2 ...
# [Prompt Expansion] Create an animated video featuring an abstract, colorful background with smooth gradients and flowing shapes to convey an inspiring atmosphere. In the center, display the following motivational quote in bold, clear English text: 'Your potential is endless; keep pushing forward.' The text should be large, legible, and contrasted against the background to stand out. Use a subtle animation effect on the text (like a slight glow or fade-in effect) and keep it visible for at least 5-10 seconds. The background should have gentle, continuous movement to make the visual engaging without distracting from the message, professional detail, creative, positive spiritual, dramatic, deep colors, detailed, attractive, cinematic, highly decorated, intricate, very inspirational, stunning, brilliant, thought flawless
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 1.92 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.23 seconds
# 100% 30/30 [00:26<00:00,  1.11it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2024-11-07/log.html
# Generating and saving time: 30.99 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
#  53% 16/30 [00:14<00:13,  1.08it/s]Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 152, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 1120, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2201, in block_thread
#     print("Keyboard interruption in main thread... closing server.")
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://34c517f5a26fb682d3.gradio.live
# terminate called without an active exception
